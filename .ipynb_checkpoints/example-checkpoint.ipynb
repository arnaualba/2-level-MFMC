# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, PowerTransformer
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline

from src.LassoFixedN import LassoFixedN
from src.two_level_MC import get_two_level_estimates

np.random.seed(42)

# %% [markdown]
# # Input generator

# %%
d = 1000  # Input dimension.

def gen_input(N):
    return np.random.randn(N,d)

# %% [markdown]
# # High-Fidelity Model

# %% [markdown]
# The goal is to compute the moments of the high-fidelity model's output.

# %%
# Dummy high-fidelity model. In reality this would be a computationally expensive physics simulation.
coefs = np.concatenate([np.array([1,2,5,10,20,50,100]), 1000*np.ones(d-7)])
intercept = 1.0

def hi_fi_model(xs):
    return np.matmul(xs, 1/coefs) + intercept

N = 500
xs = gen_input(N)
ys = hi_fi_model(xs)

fig, axs = plt.subplots(2,2, figsize = (8,8))
axs = axs.reshape(-1)
# fig.suptitle()
for i,dim in enumerate([0,1,2,3]):
    axs[i].plot(xs[:, dim], ys, 'o')
    axs[i].set_title('dim ' + str(dim) + ' vs y')
    
plt.show()

# %%
# The true values of the moments that we want to estimate:
ys = hi_fi_model(gen_input(10**4))
true_moments = np.array([np.mean(ys), np.var(ys, ddof=1), np.mean((ys - ys.mean())**3)])
true_moments
# Out:
# array([ 0.99349735,  1.25249398, -0.01334225])

# %% [markdown]
# ## Similar high-fidelity model

# %% [markdown]
# Similar model from the same "family" of UQ problems.

# %%
intercept_similar_model = 5.0
coefs_similar_model = coefs * 0.2 + np.random.rand(d)
def similar_hi_fi_model(xs):
    return np.matmul(xs, 1/coefs_similar_model) + intercept_similar_model

# %%
# Test correlation between models. MFMC works best when models are correlated.
N = 500
xs = gen_input(N)
ys = hi_fi_model(xs)
ys_similar = similar_hi_fi_model(xs)
print("Correlation between models {:.3f}".format(np.corrcoef(ys, ys_similar)[0,1]))

fig, axs = plt.subplots(1,2,figsize = (8,4))
axs[0].plot(ys, ys_similar, 'o')
axs[0].set_xlabel('High-fidelity model')
axs[0].set_ylabel('Similar high-fidelity model')

axs[1].hist(ys, bins = 50, label = 'High-fidelity Model', density = True)
axs[1].hist(ys_similar, bins = 50, label = 'Similar high-fidelity model', density = True, alpha = 0.8)
axs[1].legend()

plt.show()
# Out:
# Correlation between models 0.964

# %% [markdown]
# # Train Low-Fidelity Model

# %%
# Training data.
# We assume that sampling from the high-fidelity model is expensive, 
# but we have available data from previous simulations with a similar model

Ntr = 500
xs_tr = gen_input(Ntr)
ys_tr = similar_hi_fi_model(xs_tr)

# %%
regressor = Pipeline([('scaler', StandardScaler()),
                      ('reg', LassoFixedN(Nfeat = 0.95,
                                          output_scaler = PowerTransformer()
                                         )),
                     ])
regressor.fit(xs_tr, ys_tr)
low_fi_model = regressor.predict
ys_tr_low_fi = low_fi_model(xs_tr)

# %%
# Visualise low-fi model vs training data
fig, axs = plt.subplots(2,2, figsize = (8,8))
axs = axs.reshape(-1)
fig.suptitle('low-fidelity model vs training data')
for i,dim in enumerate([0,1,2,4]):
    axs[i].plot(xs_tr[:, dim], ys_tr, 'o', color = 'blue', label = 'Training data from similar hi-fi model')
    axs[i].plot(xs_tr[:, dim], ys_tr_low_fi, '.', color = 'orange', label = 'Low-fi predictions')
    axs[i].set_title('dim ' + str(dim) + ' vs y')
axs[-1].legend(loc = 'upper right')
    
plt.show()

# %% [markdown]
# # Compute moments of high-fidelity output

# %%
Nmax = 10**3
len_N = 20
Ns = np.logspace(1,np.log10(Nmax), len_N, dtype = int)
M = 10**5

# The high-fidelity model is executed only Nmax times.
xs = gen_input(Nmax)
ys = hi_fi_model(xs)

# The low-fidelity model is executed Nmax + M times.
ys_low_fi = low_fi_model(xs)
zs = gen_input(M)
ys_low_fi_M = low_fi_model(zs)

moments_MC = np.zeros((len_N, 3))
moments_MFMC = np.zeros((len_N, 3))

RMSEs_MC = np.zeros((len_N, 3))
RMSEs_MFMC = np.zeros((len_N, 3))

# %%
for i,N in enumerate(Ns):
    results = get_two_level_estimates(ys[:N], ys_low_fi[:N], ys_low_fi_M, 
                                      calculate_MSEs = True, adjust_alpha = True)
    
    print("Alpha = ", results['alpha'])
    moments_MC[i] = results['moments MC'][:3]  # Mean, variance, skewness, kurtosis
    moments_MFMC[i] = results['moments MFMC'][:3]
    
    # The MSE can be split into a part that converges as 1/M, and a part that converges as 1/N
    # For example, the MSE of the mean estimation cna be split as
    print("The M samples are responsible for the variance {:.2e}".format(results['Vars surr'][0]))
    print("The N samples are responsible for the variance {:.2e}".format(results['Vars comb'][0]))
    # Generally "Vars comb" should be bigger because N<<M
    
    RMSEs_MC[i] = np.sqrt(results['MSEs MC'][:3])
    RMSEs_MFMC[i] = np.sqrt(results['MSEs MFMC'][:3])
# Out:
# Alpha =  0.28287283647414385
# The M samples are responsible for the variance 1.05e-05
# The N samples are responsible for the variance 8.51e-03
# Alpha =  0.28545275216315197
# The M samples are responsible for the variance 1.07e-05
# The N samples are responsible for the variance 5.87e-03
# Alpha =  0.29936275812065805
# The M samples are responsible for the variance 1.17e-05
# The N samples are responsible for the variance 5.38e-03
# Alpha =  0.3035835128557434
# The M samples are responsible for the variance 1.21e-05
# The N samples are responsible for the variance 3.81e-03
# Alpha =  0.31698093048209197
# The M samples are responsible for the variance 1.32e-05
# The N samples are responsible for the variance 2.71e-03
# Alpha =  0.3113258943255363
# The M samples are responsible for the variance 1.27e-05
# The N samples are responsible for the variance 2.40e-03
# Alpha =  0.3096137967257471
# The M samples are responsible for the variance 1.26e-05
# ...

# %%
fig, axs = plt.subplots(1, 3, figsize = (14,5))
axs = axs.reshape(-1)

for i,moment in enumerate(['mean', 'variance', 'skewness']):
    axs[i].plot(Ns, moments_MC[:,i], label = 'MC', lw = 3)
    axs[i].plot(Ns, moments_MFMC[:,i], label = r'$\alpha$-MFMC', lw = 3, ls = '--')
    axs[i].axhline(true_moments[i], ls = '--', color = 'k', lw = 3, label = "true value")
#     axs[i].set_title('Estimation of ' + moment)
    axs[i].set_xlabel('N')
    axs[i].set_ylabel(moment)
    axs[i].set_xscale('log')
    
axs[-1].legend()
fig.subplots_adjust(wspace = .3)
plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize = (14,5))
axs = axs.reshape(-1)

for i,moment in enumerate(['mean', 'variance', 'skewness']):
    axs[i].plot(Ns, RMSEs_MC[:,i], label = 'MC', lw = 3)
    axs[i].plot(Ns, RMSEs_MFMC[:,i], label = r'$\alpha$-MFMC', lw = 3, ls = '--')
    axs[i].set_xlabel('N')
    axs[i].set_ylabel('Standard Error for Estimation of ' + moment)
    axs[i].set_xscale('log')
    axs[i].set_yscale('log')
    
axs[-1].legend()
fig.subplots_adjust(wspace = .5)
plt.show()
